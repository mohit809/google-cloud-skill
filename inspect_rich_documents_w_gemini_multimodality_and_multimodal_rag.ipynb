# %% [markdown]
# <div style="background: linear-gradient(135deg, #171520, #2c283f); padding: 32px; border-radius: 16px; border-left: 6px solid #ff7e5f; color: white; font-family: 'Segoe UI', system-ui, -apple-system, sans-serif; box-shadow: 0 12px 35px rgba(0,0,0,0.4); position: relative; overflow: hidden;">
# <div style="position: absolute; top: -50px; right: -30px; width: 180px; height: 180px; background: #ff7e5f; opacity: 0.12; filter: blur(60px); border-radius: 50%;"></div>
# <div style="position: absolute; bottom: -50px; left: 10%; width: 220px; height: 220px; background: #1a73e8; opacity: 0.12; filter: blur(70px); border-radius: 50%;"></div>
# <div style="display: flex; justify-content: space-between; align-items: center; flex-wrap: wrap; gap: 25px; position: relative; z-index: 1;">
# <div style="display: flex; align-items: center; gap: 24px;">
# <div style="background: rgba(255, 255, 255, 0.04); padding: 14px; border-radius: 16px; border: 1px solid rgba(255, 255, 255, 0.1); backdrop-filter: blur(12px); display: flex; align-items: center; justify-content: center; width: 85px; height: 85px; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
# <img src="logo.png" alt="Orbit of Ops Logo" style="max-width: 100%; max-height: 100%; object-fit: contain;" />
# </div>
# <div>
# <h1 style="color: #ffffff; margin: 0; font-size: 2.3em; font-weight: 800; letter-spacing: 0.5px; text-shadow: 0 2px 5px rgba(0,0,0,0.3);">🪐 Orbit of Ops Workspace</h1>
# <p style="font-size: 1.15em; color: #a5b4cb; margin-top: 8px; margin-bottom: 0; font-weight: 500;">Advanced AI Research Foundations &amp; <span style="color: #ffffff;">Small Language Model Laboratory</span></p>
# </div>
# </div>
# <div style="background: rgba(255, 255, 255, 0.05); padding: 12px 22px; border-radius: 30px; border: 1px solid rgba(255, 255, 255, 0.15); backdrop-filter: blur(8px); box-shadow: 0 4px 15px rgba(0,0,0,0.15);">
# <span style="font-size: 0.95em; display: flex; align-items: center; gap: 10px;">
# <span style="font-size: 1.2em;">▶️</span>
# <strong style="color: #e2e8f0; font-weight: 600;">YouTube &amp; Socials:</strong>
# <code style="background: rgba(255, 126, 95, 0.15); color: #ff9b85; padding: 6px 12px; border-radius: 8px; font-weight: 700; font-family: 'Fira Code', ui-monospace, monospace; border: 1px solid rgba(255, 126, 95, 0.3);">@orbitofops</code>
# </span>
# </div>
# </div>
# <hr style="border: none; border-top: 1px solid rgba(255, 255, 255, 0.12); margin: 28px 0; position: relative; z-index: 1;">
# <div style="display: flex; justify-content: space-between; font-size: 0.95em; flex-wrap: wrap; position: relative; z-index: 1; gap: 15px;">
# <div style="display: flex; align-items: center; gap: 10px; background: rgba(0, 0, 0, 0.25); padding: 10px 18px; border-radius: 10px; border: 1px solid rgba(255, 255, 255, 0.05);">
# <span style="font-size: 1.2em;">🔒</span>
# <span style="color: #8c9eae; font-weight: 500;">Environment:</span>
# <span style="color: #e2e8f0; font-weight: 600; letter-spacing: 0.3px;">Sensitive Data Processing</span>
# </div>
# <div style="display: flex; align-items: center; gap: 10px; background: rgba(0, 0, 0, 0.25); padding: 10px 18px; border-radius: 10px; border: 1px solid rgba(255, 255, 255, 0.05);">
# <span style="font-size: 1.2em;">🚀</span>
# <span style="color: #8c9eae; font-weight: 500;">Ecosystem:</span>
# <span style="color: #ff9b85; font-weight: 600; letter-spacing: 0.3px;">Autonomous Operations &amp; NLP</span>
# </div>
# </div>
# </div>

# %% [markdown]
# # Inspect Rich Documents with Gemini Multimodality and Multimodal RAG Challenge Lab
#
# __Note__: if you encounter an authentication error when running the cells in the notebook, go to __Vertex AI__ > __Dashboard__, and click on __Enable All Recommended APIs__. Then, re-run the failed cell, and continue the lab.
#
# ## Setup and requirements
#
# ### Install Vertex AI SDK for Python and other dependencies
#
# Run the following four cells below before you get to Task 1. Be sure to add your current project ID to the cell titled __Define Google Cloud project information__.

# %%
# RUN THIS CELL AS IS

# Install required Python packages
# %pip install --upgrade --user google-cloud-aiplatform
# %pip install --upgrade --user google-cloud-aiplatform pymupdf
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /opt/micromamba/lib/python3.12/site-packages (1.130.0)
# Collecting google-cloud-aiplatform
#   Downloading google_cloud_aiplatform-1.163.0-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.33.0)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-cloud-aiplatform)
#   Downloading google_auth-2.56.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi>=2023.7.22 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (2026.7.22)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.28.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (26.2)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=1.32.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.42.2)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.18.0)
# Collecting google-genai<3.0.0,>=1.66.0 (from google-cloud-aiplatform)
#   Downloading google_genai-2.15.0-py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: pydantic<3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.13.4)
# Requirement already satisfied: typing_extensions in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (4.16.0)
# Requirement already satisfied: docstring_parser<1 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.33.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.83.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.83.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/micromamba/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/micromamba/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (42.0.8)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-storage<4.0.0,>=1.32.0->google-cloud-aiplatform) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (4.14.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (1.9.0)
# Requirement already satisfied: sniffio in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/micromamba/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (3.18)
# Requirement already satisfied: httpcore==1.* in /opt/micromamba/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/micromamba/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/micromamba/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/micromamba/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/micromamba/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/micromamba/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/micromamba/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/micromamba/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: cffi>=1.12 in /opt/micromamba/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (2.1.0)
# Requirement already satisfied: pycparser in /opt/micromamba/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/micromamba/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.6.4)
# Downloading google_cloud_aiplatform-1.163.0-py2.py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 50.6 MB/s  0:00:00
# Downloading google_auth-2.56.2-py3-none-any.whl (258 kB)
# Downloading google_genai-2.15.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.7 MB/s  0:00:00
# Installing collected packages: google-auth, google-genai, google-cloud-aiplatform
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 2/3 [google-cloud-aiplatform]  WARNING: The script tb-gcp-uploader is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [google-cloud-aiplatform]
# Successfully installed google-auth-2.56.2 google-cloud-aiplatform-1.163.0 google-genai-2.15.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-cloud-aiplatform in ./.local/lib/python3.12/site-packages (1.163.0)
# Collecting pymupdf
#   Downloading pymupdf-1.28.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.33.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in ./.local/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.56.2)
# Requirement already satisfied: certifi>=2023.7.22 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (2026.7.22)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.28.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (26.2)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=1.32.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.42.2)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.18.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.66.0 in ./.local/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.15.0)
# Requirement already satisfied: pydantic<3 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.13.4)
# Requirement already satisfied: typing_extensions in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (4.16.0)
# Requirement already satisfied: docstring_parser<1 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-aiplatform) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.33.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.83.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in /opt/micromamba/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.83.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/micromamba/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/micromamba/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (42.0.8)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in /opt/micromamba/lib/python3.12/site-packages (from google-cloud-storage<4.0.0,>=1.32.0->google-cloud-aiplatform) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (4.14.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (1.9.0)
# Requirement already satisfied: sniffio in /opt/micromamba/lib/python3.12/site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/micromamba/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (3.18)
# Requirement already satisfied: httpcore==1.* in /opt/micromamba/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/micromamba/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/micromamba/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/micromamba/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/micromamba/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/micromamba/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/micromamba/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/micromamba/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: cffi>=1.12 in /opt/micromamba/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (2.1.0)
# Requirement already satisfied: pycparser in /opt/micromamba/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/micromamba/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.6.4)
# Downloading pymupdf-1.28.0-cp310-abi3-manylinux_2_28_x86_64.whl (25.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.7/25.7 MB 76.4 MB/s  0:00:006m0:00:01
# Installing collected packages: pymupdf
#   WARNING: The script pymupdf is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pymupdf-1.28.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Restart current runtime
#
# You must restart the runtime in order to use the newly installed packages in this Jupyter runtime. You can do this by running the cell below, which will restart the current kernel.

# %%
# "RUN THIS CELL AS IS"

import IPython

# Restart the kernel after libraries are loaded.

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ The kernel is going to restart. Please wait until it is finished before continuing to the next step. ⚠️</b>
# </div>

# %% [markdown]
# ### Define Google Cloud project information

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

import sys

# Define project information and update the location if it differs from the one specified in the lab instructions.
PROJECT_ID = !gcloud config get project
PROJECT_ID = PROJECT_ID[0]  # @param {type:"string"}
LOCATION = !gcloud compute project-info describe --format="value(commonInstanceMetadata.items[google-compute-default-region])"
LOCATION = LOCATION[0]  # @param {type:"string"}

# Try to get the PROJECT_ID automatically.
if "google.colab" not in sys.modules:
    import subprocess

    PROJECT_ID = subprocess.check_output(
        ["gcloud", "config", "get-value", "project"], text=True
    ).strip()

print(f"Your project ID is: {PROJECT_ID}")
print(f"Your location is: {LOCATION}")
# Out:
# Your project ID is: qwiklabs-gcp-01-56b5381bdfb0
# Your location is: us-east4

# %% [markdown]
# ### Initialize Vertex AI
#
# Initialize the Vertex AI SDK for Python for your project:

# %%
# "RUN THIS CELL AS IS"

# Initialize Vertex AI.
import vertexai
vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# ## Task 1. Generating Multimodal Insights with Gemini
#
# Gemini is multimodal model that supports multimodal prompts. You can include text, image(s), and video in your prompt requests and get text or code responses.
#
# To complete Task 1, follow the instructions at the top of each notebook cell:
# * Run the cells with the comment "RUN THIS CELL AS IS".
# * Complete and run the cells with the comment "COMPLETE THE MISSING PART AND RUN THIS CELL".
#
# __Note__: Ensure you can see the weather related data in the response that is printed.
#
#
# ### Setup and requirements for Task 1
#
# #### Import libraries

# %%
# "RUN THIS CELL AS IS"

from vertexai.generative_models import (
    GenerationConfig,
    GenerativeModel,
    Image,
    Part,
)

# %% [markdown]
# #### Load Gemini 2.0 Flash Model

# %%
# "RUN THIS CELL AS IS"

multimodal_model = GenerativeModel("gemini-2.5-flash")
# Out:
# /home/jupyter/.local/lib/python3.12/site-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %% [markdown]
# #### Define helper functions

# %%
# "RUN THIS CELL AS IS"

import http.client
import typing
import urllib.request

import IPython.display
from PIL import Image as PIL_Image
from PIL import ImageOps as PIL_ImageOps


def display_images(
    images: typing.Iterable[Image],
    max_width: int = 600,
    max_height: int = 350,
) -> None:
    for image in images:
        pil_image = typing.cast(PIL_Image.Image, image._pil_image)
        if pil_image.mode != "RGB":
            # RGB is supported by all Jupyter environments (e.g. RGBA is not yet)
            pil_image = pil_image.convert("RGB")
        image_width, image_height = pil_image.size
        if max_width < image_width or max_height < image_height:
            # Resize to display a smaller notebook image
            pil_image = PIL_ImageOps.contain(pil_image, (max_width, max_height))
        IPython.display.display(pil_image)


def get_image_bytes_from_url(image_url: str) -> bytes:
    with urllib.request.urlopen(image_url) as response:
        response = typing.cast(http.client.HTTPResponse, response)
        image_bytes = response.read()
    return image_bytes


def load_image_from_url(image_url: str) -> Image:
    image_bytes = get_image_bytes_from_url(image_url)
    return Image.from_bytes(image_bytes)


def display_content_as_image(content: str | Image | Part) -> bool:
    if not isinstance(content, Image):
        return False
    display_images([content])
    return True


def display_content_as_video(content: str | Image | Part) -> bool:
    if not isinstance(content, Part):
        return False
    part = typing.cast(Part, content)
    file_path = part.file_data.file_uri.removeprefix("gs://")
    video_url = f"https://storage.googleapis.com/{file_path}"
    IPython.display.display(IPython.display.Video(video_url, width=600))
    return True


def print_multimodal_prompt(contents: list[str | Image | Part]):
    """
    Given contents that would be sent to Gemini,
    output the full multimodal prompt for ease of readability.
    """
    for content in contents:
        if display_content_as_image(content):
            continue
        if display_content_as_video(content):
            continue
        print(content)

# %% [markdown]
# ### Task 1.1. Image understanding across multiple images

# %%
# "RUN THIS CELL AS IS"

# You're going to work with provided variables in this task. 
# First, review and describe the content/purpose of each variable below. 

image_ask_first_1_url = "https://storage.googleapis.com/spls/gsp520/Google_Branding/Ask_first_1.png"
image_dont_do_this_1_url = "https://storage.googleapis.com/spls/gsp520/Google_Branding/Dont_do_this_1.png"
image_ask_first_1 = load_image_from_url(image_ask_first_1_url)
image_dont_do_this_1 = load_image_from_url(image_dont_do_this_1_url)

instructions = "Instructions: Consider the following image that contains text:"
prompt1 = "What is the title of this image"
prompt2 = """
Answer the question through these steps:
Step 1: Identify the title of each image by using the filename of each image.
Step 2: Describe the image.
Step 3: For each image, describe the actions that a user is expected to take.
Step 4: Extract the text from each image as a full sentence.
Step 5: Describe the sentiment for each image with an explanation.

Answer and describe the steps taken:
"""

# %% [markdown]
# #### Create an input for the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to create an input for your multimodal model. Create your contents list using the variables above. Ensure the structure matches the format expected by the multimodal model.

contents = [
    instructions,
    image_ask_first_1,
    prompt1,
    image_dont_do_this_1,
    prompt2,
]

# %% [markdown]
# #### Generate responses from the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the next part of this task, you're going to generate responses from the multimodal model. Capture the output of the model in the "responses" variable by using your "contents" list.

responses = multimodal_model.generate_content(contents, stream=True)

# %% [markdown]
# #### Display the prompt and responses

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the last part of this task, you're going to print your contents and responses with the prompt and responses title provided. Use descriptive titles to help organize the output (e.g., "Prompts", "Model Responses") and then display the prompt and responses by using the print() function. 

# Hint: "\n" inserts a newline character for clearer separation between the sections.

print("-------Prompt-------")
print_multimodal_prompt(contents)

print("\n-------Response-------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt-------
# Instructions: Consider the following image that contains text:
# <PIL.Image.Image image mode=RGB size=328x350>
# What is the title of this image
# <PIL.Image.Image image mode=RGB size=328x350>
# Answer the question through these steps:
# Step 1: Identify the title of each image by using the filename of each image.
# Step 2: Describe the image.
# Step 3: For each image, describe the actions that a user is expected to take.
# Step 4: Extract the text from each image as a full sentence.
# Step 5: Describe the sentiment for each image with an explanation.
#
# Answer and describe the steps taken:
#
#
# -------Response-------
# Here are the steps and the answer:
#
# **Step 1: Identify the title of each image by using the filename of each image.**
# *   **Image 1 Title:** "Product icons" (derived from the heading below the image).
# *   **Image 2 Title:** "Don't imply endorsement." (derived from the heading below the image).
#
# **Step 2: Describe the image.**
# *   **Image 1 Description:** The image displays a screenshot or mockup of a mobile application or website interface. It features a prominent blue logo with intertwined X-shapes, the brand name "SYSTEMERGER," and a tagline "Merge your system workflow to make your job easier." Below this, it lists "works with apps like these:" followed by small icons for Gmail, Google Calendar, and Google Drive. The text below the image highlights the topic of "Product icons" and advises users to refer to usage guidelines.
# *   **Image 2 Description:** The image showcases a blue circular logo containing an anchor symbol, accompanied by the text "FRANK'S CRAB SHACK" in large blue lettering. Below this, in smaller text, it reads "#1 Crab Restaurant in Northeastern Maine on" followed by the Google logo. The text below the image provides a clear warning about not implying endorsement or affiliation with Google.
#
# **Step 3: For each image, describe the actions that a user is expected to take.**
# *   **Image 1 Expected Action:** Users are expected to refer to the "icon usage guidelines" to understand the rules and conditions for using product icons in association with their own business. This implies a need for research and compliance.
# *   **Image 2 Expected Action:** Users are expected to *not* use the Google logo or other Google brand elements in a way that suggests affiliation, endorsement, or sponsorship if such a relationship does not genuinely exist. This is a directive to avoid misleading branding practices.
#
# **Step 4: Extract the text from each image as a full sentence.**
# *   **Image 1 Extracted Text:** The text within the image includes: "systemerger", "SYSTEMERGER", "Merge your system workflow to make your job easier", and "works with apps like these:". The text associated with the image is: "Product icons. Refer to our icon usage guidelines to see whether you can use certain product icons in association with your business."
# *   **Image 2 Extracted Text:** The text within the image includes: "FRANK'S CRAB SHACK", "#1 Crab Restaurant in Northeastern Maine on Google". The text associated with the image is: "Don't imply endorsement. Don't use the Google logo or any of our brand elements in any way that implies affiliation, endorsement, or sponsorship where such a relationship does not exist."
#
# **Step 5: Describe the sentiment for each image with an explanation.**
# *   **Image 1 Sentiment:** The sentiment is **informative and advisory**. The image itself provides an example of app integration, and the accompanying text, marked with an exclamation symbol, informs the user about the importance of checking guidelines for using product icons. It's guiding users on how to comply.
# *   **Image 2 Sentiment:** The sentiment is **cautionary and prohibitive**. The image presents an example (likely an inappropriate one) of Google's logo use, and the accompanying text, marked with a red 'X', explicitly warns and forbids users from implying false endorsement or affiliation with Google. It's a strong directive against misuse.
#
# ---
#
# **Answer to the question "What is the title of this image":**
#
# The title of the first image is **Product icons**.

# %% [markdown]
# ### To verify your work for Task 1.1, click __Check my progress__ in the lab instructions.

# %% [markdown]
# ### Task 1.2. Similarity/Differences between images
#
# #### Explore the variables of the task

# %%
# "RUN THIS CELL AS IS"

# You're going to work with provided variables in this task. First, review and describe the content/purpose of each variable below. 


image_ask_first_3_url = "https://storage.googleapis.com/spls/gsp520/Google_Branding/Ask_first_3.png"
image_dont_do_this_3_url =  "https://storage.googleapis.com/spls/gsp520/Google_Branding/Dont_do_this_3.png"
image_ask_first_3 = load_image_from_url(image_ask_first_3_url)
image_dont_do_this_3 = load_image_from_url(image_dont_do_this_3_url)

prompt1 = """
Consider the following two images:
Image 1:
"""
prompt2 = """
Image 2:
"""
prompt3 = """
1. What is shown in Image 1 and Image 2?
2. What is similar between the two images?
3. What is difference between Image 1 and Image 2 in terms of the text ?
"""

# %% [markdown]
# #### Create an input for the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to create an input for your multimodal model. Create your contents list using the variables above. Ensure the structure matches the format expected by the multimodal model.

contents = [prompt1, image_ask_first_3, prompt2, image_dont_do_this_3, prompt3]

# %% [markdown]
# #### Set configuration parameters

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to set configuration parameters that will influence how the multimodal model generates text. These settings control aspects like the creativity and focus of the responses. Here's how:
# Temperature: Controls randomness. Lower values mean more predictable results, higher values mean more surprising and creative output
# Top p / Top k: Affects how the model chooses words. Explore different values to see how they change the results.
# Other parameters: Check the model's documentation for additional options you might want to adjust.

# Store your configuration parameters in a generation_config variable. This improves reusability, allowing you to easily apply the same settings across tasks and make adjustments as needed.

generation_config = GenerationConfig(
    temperature=0.0,
    top_p=0.8,
    top_k=40,
    candidate_count=1,
    max_output_tokens=2048,
)

# %% [markdown]
# #### Generate responses from the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the next part of this task, you're going to generate responses from a multimodal model. capture the output of the model in the "responses" variable by using your "contents" list and the confiuguration settings.


responses = multimodal_model.generate_content(
    contents,
    generation_config=generation_config,
    stream=True,
)

# %% [markdown]
# #### Display the prompt and responses

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the last part of this task, you're going to print your contents and responses with the prompt and responses title provided. Use descriptive titles to help organize the output (e.g., "Prompts", "Model Responses") and then display the prompt and responses by using the print() function. 

# Hint: "\n" inserts a newline character for clearer separation between the sections.

print("-------Prompt-------")
print_multimodal_prompt(contents)

print("\n-------Response-------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt-------
#
# Consider the following two images:
# Image 1:
# <PIL.Image.Image image mode=RGB size=320x350>
# Image 2:
# <PIL.Image.Image image mode=RGB size=322x350>
# 1. What is shown in Image 1 and Image 2?
# 2. What is similar between the two images?
# 3. What is difference between Image 1 and Image 2 in terms of the text ?
#
#
# -------Response-------
# Here's an analysis of the two images:
#
# 1.  **What is shown in Image 1 and Image 2?**
#     *   **Image 1:** Shows a website announcement from the Wisahawkeen Public Library about a new "Grow with Google" partnership. The image prominently features the "Grow with Google PARTNER" logo. Below the image, there's text providing guidance on "Sponsorships and partnerships" with Google, advising existing partners on how to submit requests.
#     *   **Image 2:** Displays a logo for "Finder.ly" which uses a color scheme and design elements (like the angled background colors) that are highly reminiscent of Google's branding. Below the image, there's a clear warning from Google stating, "Don't imitate our logo or visual identity," and elaborating on what constitutes imitation (color combinations, graphic designs, etc.).
#
# 2.  **What is similar between the two images?**
#     *   **Google Connection:** Both images are directly related to Google's brand and identity. Image 1 shows a legitimate partnership *with* Google, while Image 2 shows a warning *from* Google about imitating its brand.
#     *   **Branding/Visual Identity:** Both deal with Google's visual identity. Image 1 showcases Google's official "Grow with Google" branding, and Image 2 warns against unauthorized imitation of Google's visual identity.
#     *   **Color Palette:** The distinctive primary colors associated with Google (blue, red, yellow, green) are present in the "Grow with Google" logo in Image 1 and are explicitly imitated in the "Finder.ly" logo in Image 2, which is the subject of the warning.
#     *   **Guidance/Rules:** Both images are accompanied by text that provides guidelines or rules regarding interaction with Google's brand.
#
# 3.  **What is difference between Image 1 and Image 2 in terms of the text?**
#     *   **Purpose/Tone:**
#         *   **Image 1 text:** Is informative and facilitative. It provides instructions on *how* to engage in a legitimate partnership with Google if you already have a relationship. The tone is helpful and guiding.
#         *   **Image 2 text:** Is prohibitive and cautionary. It explicitly states what *not* to do – "Don't imitate our logo or visual identity." The tone is protective and warning.
#     *   **Action Encouraged/Discouraged:**
#         *   **Image 1 text:** Encourages a specific action: "reach out to your Google contact to submit your request."
#         *   **Image 2 text:** Discourages a specific action: imitating Google's branding.
#     *   **Iconography:**
#         *   **Image 1:** Uses an orange exclamation mark icon, typically indicating important information or a tip.
#         *   **Image 2:** Uses a red 'X' icon, universally signifying prohibition, error, or something to avoid.
#     *   **Subject Matter:**
#         *   **Image 1 text:** Focuses on the process for *sponsorships and partnerships* with Google.
#         *   **Image 2 text:** Focuses on the prohibition of *imitating Google's logo or visual identity*.

# %% [markdown]
# ### To verify your work for Task 1.2, click __Check my progress__ in the lab instructions.

# %% [markdown]
# ### Task 1.3. Generate a video description
#
# #### Explore the variables of the task

# %%
# "RUN THIS CELL AS IS"

# You're going to work with provided variables in this task. 
# First, review and describe the content/purpose of each variable below. 


prompt = """
What is the product shown in this video?
What specific product features are highlighted in the video?
Where was this video filmed? Which cities around the world could potentially serve as the background in the video?
What is the sentiment of the video?
"""
video = Part.from_uri(
    uri="gs://spls/gsp520/google-pixel-8-pro.mp4",
    mime_type="video/mp4",
)

# %% [markdown]
# #### Create an input for the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to create an input for your multimodal model. Create your contents list using the variables above. Ensure the structure matches the format expected by the multimodal model.

contents = [prompt, video]

# %% [markdown]
# #### Generate responses from the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the next part of this task, you're going to generate responses from a multimodal model. Capture the output of the model in the "responses" variable by using your "contents" list.


responses = multimodal_model.generate_content(contents, stream=True)

# %% [markdown]
# #### Display the prompt and responses
#
# **Note:** If you encounter any authentication error below cell run, go to the **Navigation menu**, click **Vertex AI > Dashboard**, then click **"Enable all Recommended APIs"** Now, go back to cell 16, and run cells 16, 17 and below cell.

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the last part of this task, you're going to print your contents and responses with the prompt and responses title provided. Use descriptive titles to help organize the output (e.g., "Prompts", "Model Responses") and then display the prompt and responses by using the print() function. 

# Hint: "\n" inserts a newline character for clearer separation between the sections.

print("-------Prompt-------")
print_multimodal_prompt(contents)

print("\n-------Response-------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt-------
#
# What is the product shown in this video?
# What specific product features are highlighted in the video?
# Where was this video filmed? Which cities around the world could potentially serve as the background in the video?
# What is the sentiment of the video?
# <video src="https://storage.googleapis.com/spls/gsp520/google-pixel-8-pro.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# -------Response-------
# Here's an analysis of the video:
#
# *   **What is the product shown in this video?**
#     The product shown is the **Google Pixel 8 Pro** smartphone.
#
# *   **What specific product features are highlighted in the video?**
#     The video highlights several AI-powered features of the Google Pixel 8 Pro:
#     1.  **Magic Eraser (0:06):** Used to remove unwanted people or objects from a photo, as demonstrated by making background people disappear from a jumping shot.
#     2.  **Audio Magic Eraser (0:11-0:13):** Used to reduce background noise in videos, shown by making a dog's barking less prominent in a video of a baby.
#     3.  **Best Take (0:15-0:17):** Used to combine multiple shots to ensure everyone in a group photo has their best expression, illustrated by changing one person's facial expression from neutral to smiling in a selfie.
#     4.  **Magic Editor (0:20-0:21):** A more advanced editing tool used to remove or reposition objects in a photo, demonstrated by removing a picnic table from a basketball dunk shot.
#
# *   **Where was this video filmed? Which cities around the world could potentially serve as the background in the video?**
#     The video appears to be filmed in **London, UK**.
#     *   The grand, light-colored stone architecture at the beginning (0:00-0:07) is characteristic of central London's historic buildings (e.g., around Trafalgar Square, Westminster, Embankment).
#     *   The red brick buildings, graffiti, and the style of the apartment blocks (council estates) in the basketball court scene (0:18-0:23) are very typical of urban areas in London.
#
#     Other cities around the world that *could potentially* serve as a background for some of these scenes (though less likely for the combination of all elements) include:
#     *   **Paris:** For the grand, Haussmannian architecture.
#     *   **Dublin/Edinburgh:** For some older European architectural styles.
#     *   **New York City/Chicago:** For some urban basketball court aesthetics, though the specific brick architecture is less common.
#
# *   **What is the sentiment of the video?**
#     The sentiment of the video is overwhelmingly **positive, energetic, and empowering**.
#     *   **Upbeat Music:** The constant, catchy hip-hop soundtrack sets a lively and confident tone.
#     *   **Joyful Scenes:** People are smiling, laughing, dancing, and showing excitement. The baby is happy, and the friends are amazed by the phone's capabilities.
#     *   **Emphasis on Ease and Fun:** The features are presented as effortless ways to "make it pop," "make it clear," "make everyone happy," and "change everything," suggesting that the phone enhances user creativity and satisfaction.
#     *   **Confidence in AI:** The repeated emphasis on "AI" highlights advanced technology that makes complex tasks simple and fun, leading to impressive results.

# %% [markdown]
# Proceed to Task 1.4 below (no progress check for Task 1.3 in lab instructions).
#
# ### Task 1.4. Extract tags of objects throughout the video
#
# #### Explore the variables of the task

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# You're going to work with provided variables in this task. First, review and describe the content/purpose of each variable below. 

prompt = """
Answer the following questions using the video only:

Which particular sport is highlighted in the video?
What values or beliefs does the advertisement communicate about the brand?
What emotions or feelings does the advertisement evoke in the audience?
Which tags associated with objects featured throughout the video could be extracted?
"""
video = Part.from_uri(
    uri="gs://spls/gsp520/google-pixel-8-pro.mp4",
    mime_type="video/mp4",
)

# %% [markdown]
# #### Create an input for the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to create an input for your multimodal model. Create your contents list using the variables above. Ensure the structure matches the format expected by the multimodal model.

contents = [prompt, video]

# %% [markdown]
# #### Generate responses from the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the next part of this task, you're going to generate responses from a multimodal model. capture the output of the model in the "responses" variable by using your "contents" list and video input.

responses = multimodal_model.generate_content(contents, stream=True)

# %% [markdown]
# #### Display the prompt and responses

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the last part of this task, you're going to print your contents and responses with the prompt and responses title provided. Use descriptive titles to help organize the output (e.g., "Prompts", "Model Responses") and then display the prompt and responses by using the print() function. 

# Hint: "\n" inserts a newline character for clearer separation between the sections.

print("-------Prompt-------")
print_multimodal_prompt(contents)

print("\n-------Response-------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt-------
#
# Answer the following questions using the video only:
#
# Which particular sport is highlighted in the video?
# What values or beliefs does the advertisement communicate about the brand?
# What emotions or feelings does the advertisement evoke in the audience?
# Which tags associated with objects featured throughout the video could be extracted?
# <video src="https://storage.googleapis.com/spls/gsp520/google-pixel-8-pro.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# -------Response-------
# Here are the answers to your questions based on the video:
#
# 1.  **Which particular sport is highlighted in the video?**
#     The sport highlighted in the video is **basketball**.
#
# 2.  **What values or beliefs does the advertisement communicate about the brand?**
#     The advertisement communicates that the Google Pixel 8 Pro brand values:
#     *   **Innovation and advanced technology (AI):** Emphasizing "AI to make it pop," "make it clear," and "make everyone :)" (happy/perfect).
#     *   **User empowerment and creativity:** Enabling users to easily edit photos and videos to achieve professional-looking results ("Magic Eraser," "Audio Magic Eraser," "Best Take").
#     *   **Quality and clarity:** Highlighting features that enhance image and sound quality.
#     *   **Capturing and perfecting life's moments:** Showing scenarios like family memories (baby video) and social gatherings (group selfie, sports action shot).
#     *   **Exclusivity and superior engineering:** Concluding with "Pixel. The only phone engineered by Google."
#
# 3.  **What emotions or feelings does the advertisement evoke in the audience?**
#     The advertisement primarily evokes feelings of:
#     *   **Joy and happiness:** Through the upbeat music, smiling faces, and positive outcomes of the phone's features.
#     *   **Excitement and wonder:** At the "magical" editing capabilities of the AI features.
#     *   **Satisfaction and confidence:** In being able to easily capture and perfect personal moments.
#     *   **Enthusiasm:** For new technology that enhances everyday experiences.
#     *   **Amusement:** From the playful nature of some scenes and the reactions of the characters.
#
# 4.  **Which tags associated with objects featured throughout the video could be extracted?**
#     *   Smartphone (Google Pixel 8 Pro)
#     *   People (men, women, baby, young adults, children - implied by baby)
#     *   Dogs
#     *   Basketball
#     *   Basketball hoop
#     *   Buildings (urban, residential)
#     *   Streets/Pavement
#     *   Fields/Grass/Flowers
#     *   Couch
#     *   Table (coffee table, picnic table)
#     *   Hats (beanie)
#     *   Cardigan
#     *   Jeans/Denim
#     *   Sneakers/Shoes
#     *   Jackets
#     *   T-shirts
#     *   Shorts
#     *   Earrings
#     *   Necklaces
#     *   Glasses
#     *   Graffiti
#     *   Fence
#     *   Toy

# %% [markdown]
# Proceed to Task 1.5 below (no progress check for Task 1.4 in lab instructions).
#
# ### Task 1.5. Ask more questions about a video
#
# **Note:** Although this video contains audio, Gemini does not currently support audio input and will only answer based on the video.
#
# #### Explore the variables of the task

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# You're going to work with provided variables in this task. 
# First, review and describe the content/purpose of each variable below. 


prompt = """
Answer the following questions using the video only:

How does the advertisement portray the use of technology, specifically AI, in capturing and preserving memories?
What visual cues or storytelling elements contribute to the nostalgic atmosphere of the advertisement?
How does the advertisement depict the role of friendship and social connections in enhancing experiences and creating memories?
Are there any specific features or functionalities of the phone highlighted in the advertisement, besides its AI capabilities?

Provide the answer JSON.
"""
video = Part.from_uri(
    uri="gs://spls/gsp520/google-pixel-8-pro.mp4",
    mime_type="video/mp4",
)

# %% [markdown]
# #### Create an input for the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to create an input for your multimodal model. Create your contents list using the variables above. Ensure the structure matches the format expected by the multimodal model.

contents = [prompt, video]

# %% [markdown]
# #### Generate responses from the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the next part of this task, you're going to generate responses from a multimodal model. capture the output of the model in the "responses" variable by using your "contents" list and video input.


responses = multimodal_model.generate_content(contents, stream=True)

# %% [markdown]
# #### Display the prompt and responses

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the last part of this task, you're going to print your contents and responses with the prompt and responses title provided. Use descriptive titles to help organize the output (e.g., "Prompts", "Model Responses") and then display the prompt and responses by using the print() function. 

# Hint: "\n" inserts a newline character for clearer separation between the sections.

print("-------Prompt-------")
print_multimodal_prompt(contents)

print("\n-------Response-------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt-------
#
# Answer the following questions using the video only:
#
# How does the advertisement portray the use of technology, specifically AI, in capturing and preserving memories?
# What visual cues or storytelling elements contribute to the nostalgic atmosphere of the advertisement?
# How does the advertisement depict the role of friendship and social connections in enhancing experiences and creating memories?
# Are there any specific features or functionalities of the phone highlighted in the advertisement, besides its AI capabilities?
#
# Provide the answer JSON.
# <video src="https://storage.googleapis.com/spls/gsp520/google-pixel-8-pro.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# -------Response-------
# ```json
# {
#   "q1_ai_memories": "The advertisement portrays AI as a transformative tool for capturing and preserving memories by enabling users to perfect their photos and videos. Specifically, AI is demonstrated through:\n1.  **Magic Eraser**: Used to remove unwanted elements (like people or objects) from photos, making the main subject 'pop' or creating a cleaner composition. (e.g., removing people from the background of a jumping photo, removing a table from a basketball dunk photo).\n2.  **Audio Clarity**: Identified as 'Identifying sounds...' and then allowing for the reduction of 'Noise' to make speech or specific sounds (like a baby's cry) clearer in videos, effectively 'making it clear.'\n3.  **Facial Expression Adjustment**: Shown as a feature to 'make everyone happy' by altering a person's expression in a group selfie from serious to smiling, ensuring everyone looks their best in a memory.",
#   "q2_nostalgic_cues": "The nostalgic atmosphere is created through several visual cues and storytelling elements:\n1.  **Focus on personal, relatable moments**: The advertisement showcases everyday, cherished experiences such as friends taking spontaneous photos on the street, a parent capturing their baby's cry, friends taking a group selfie in a natural setting, and friends playing basketball.\n2.  **Emphasis on shared joy and connection**: The scenes often involve groups of friends or family members, highlighting collective experiences. The excited reactions of friends viewing an edited photo and the group selfie underscore the communal aspect of memory-making.\n3.  **Idealization of memories**: The AI features are presented as tools to enhance and perfect these personal moments, suggesting a desire to preserve them in their most joyful and visually appealing form, thus evoking a sense of cherished, idealized past experiences.",
#   "q3_friendship_social_connections": "The advertisement depicts friendship and social connections as integral to enhancing experiences and creating memories in the following ways:\n1.  **Shared activities**: Friends are shown engaging in common activities like walking together, taking group selfies in a field, and playing basketball on a court.\n2.  **Mutual capture of moments**: One friend captures another's dynamic moment (e.g., jumping), and groups actively participate in taking selfies, demonstrating that memories are often created and documented within a social context.\n3.  **Collective enjoyment and validation**: The most prominent depiction is when three friends gather around the phone to excitedly view the edited photo of a basketball dunk. Their shared reactions of awe and surprise emphasize how the captured and enhanced memory strengthens their bond and amplifies the enjoyment of their shared experience.",
#   "q4_non_ai_features": "Yes, besides its AI capabilities, the advertisement highlights several other features and functionalities of the Google Pixel 8 Pro:\n1.  **Standard Photo and Video Editing Tools**: Beyond the AI-powered 'Magic Eraser,' the ad briefly shows conventional editing options within the Google Photos app, such as 'Crop,' 'Tools,' 'Adjust,' 'Filters,' and 'Save.'\n2.  **Video Recording Functionality**: The phone is shown actively recording video, displaying typical on-screen controls like play/pause and a record button.\n3.  **Multiple Camera Modes**: The camera interface is briefly visible, showcasing various modes like 'Panos' (Panorama), 'Night Sight,' 'Portrait,' and standard 'Photo' mode, indicating diverse photographic capabilities.\n4.  **Physical Design**: The phone's sleek physical appearance, specifically its light blue color, is showcased in the final shots of the advertisement."
# }
# ```

# %% [markdown]
# Proceed to Task 1.6 below (no progress check for Task 1.5 in lab instructions).
#
# ### Task 1.6. Retrieve extra information beyond the video
#
# #### Explore the variables of the task

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# You're going to work with provided variables in this task. 
# First, review and describe the content/purpose of each variable below. 


prompt = """
Answer the following questions using the video only:

How does the advertisement appeal to its target audience through its messaging and imagery?
What overall message or takeaway does the advertisement convey about the brand and its products?
Are there any symbolic elements or motifs used throughout the advertisement to reinforce its central themes?
What is the best hashtag for this video based on the description ?

"""
video = Part.from_uri(
    uri="gs://spls/gsp520/google-pixel-8-pro.mp4",
    mime_type="video/mp4",
)

# %% [markdown]
# #### Create an input for the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Now, you're going to create an input for your multimodal model. Create your contents list using the variables above. Ensure the structure matches the format expected by the multimodal model.

contents = [prompt, video]

# %% [markdown]
# #### Generate responses from the multimodal model

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the next part of this task, you're going to generate responses from a multimodal model. capture the output of the model in the "responses" variable by using your "contents" list and video input.

responses = multimodal_model.generate_content(contents, stream=True)

# %% [markdown]
# #### Display the prompt and responses

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# In the last part of this task, you're going to print your contents and responses with the prompt and responses title provided. Use descriptive titles to help organize the output (e.g., "Prompts", "Model Responses") and then display the prompt and responses by using the print() function. 

# Hint: "\n" inserts a newline character for clearer separation between the sections.

print("-------Prompt-------")
print_multimodal_prompt(contents)

print("\n-------Response-------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt-------
#
# Answer the following questions using the video only:
#
# How does the advertisement appeal to its target audience through its messaging and imagery?
# What overall message or takeaway does the advertisement convey about the brand and its products?
# Are there any symbolic elements or motifs used throughout the advertisement to reinforce its central themes?
# What is the best hashtag for this video based on the description ?
# <video src="https://storage.googleapis.com/spls/gsp520/google-pixel-8-pro.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# -------Response-------
# Here are the answers to your questions, based solely on the provided video:
#
# **How does the advertisement appeal to its target audience through its messaging and imagery?**
#
# *   **Messaging:** The advertisement uses short, punchy phrases that highlight key benefits and capabilities: "with AI," "to make it pop," "make it clear," "make everyone happy," "and change everything," and "Yep." These messages are direct, confident, and imply ease of use and powerful results. The final message, "Pixel. The only phone engineered by Google," emphasizes exclusivity and technological prowess.
# *   **Imagery:**
#     *   **Diverse and youthful cast:** Features young people in various urban and natural settings, reflecting a modern, diverse, and socially active demographic.
#     *   **Relatable scenarios:** Shows capturing everyday moments, from a stylish individual posing, to a baby babbling, to friends playing basketball and taking selfies in a field. This makes the phone's features feel relevant to a wide range of personal experiences.
#     *   **"Before and after" visuals:** Clearly demonstrates the impact of features like Magic Eraser (removing a person from a street photo, removing a table from a basketball shot), Audio Magic Eraser (reducing noise from a baby's video), and Best Take (combining expressions for a perfect group photo). This visual proof directly appeals to the desire for perfect, share-worthy content.
#     *   **Energetic music and vibrant colors:** The upbeat soundtrack and colorful visual elements (like the gradient "AI" text) create a dynamic and exciting atmosphere, suggesting that using the Pixel is fun and enhances life.
#
# **What overall message or takeaway does the advertisement convey about the brand and its products?**
#
# The overall message is that the Google Pixel 8 Pro is an incredibly smart and powerful device, driven by AI, that empowers users to effortlessly create perfect photos and videos. It conveys that the brand (Google Pixel) is at the forefront of mobile technology, offering unique and intuitive solutions for common content creation challenges. The takeaway is that the Pixel 8 Pro simplifies complex editing, making professional-quality results accessible to everyone, ensuring no moment or shot is ever ruined.
#
# **Are there any symbolic elements or motifs used throughout the advertisement to reinforce its central themes?**
#
# Yes, several symbolic elements and motifs reinforce the central themes:
#
# *   **The "AI" text graphic:** This large, colorful, gradient text explicitly highlights Artificial Intelligence as the core, unifying technology behind all the featured capabilities. It's a visual motif that appears multiple times, symbolizing the phone's intelligence and advanced processing power.
# *   **Circular selection/editing tools:** The visual representation of the Magic Eraser and the audio noise reduction tool both use prominent circular interfaces. This can symbolize focus, precision, and the phone's ability to isolate and refine specific elements within a broader context.
# *   **The act of "changing" or "making perfect":** The recurring theme of transformation—removing distractions, enhancing expressions, clarifying sound—is a powerful motif. The phrases "make it pop," "make it clear," "make everyone happy," and "change everything" verbally reinforce this idea of the phone as a tool for perfection and creative control.
# *   **Dynamic movement and expression:** The jumping person, the baby's expressions, the basketball dunk, and the group selfie all symbolize capturing peak moments and genuine human emotion, which the phone then enhances or preserves perfectly.
#
# **What is the best hashtag for this video based on the description?**
#
# Since no description was provided with the video, I will suggest a hashtag based on the video's content and its prominent messaging:
#
# **#PixelAI**
#
# This hashtag effectively captures the main selling point explicitly highlighted in the video: the integration of AI ("That's the AI. only in Google Pixel 8 Pro") to deliver advanced features.

# %% [markdown]
# ### To verify your work for Task 1.6, click __Check my progress__ in the lab instructions.

# %% [markdown]
# ## Task 2. Retrieving and integrating knowledge with multimodal retrieval augmented generation (RAG)
#
# To complete Task 2, follow the instructions at the top of each notebook cell:
# * Run the cells with the comment "RUN THIS CELL AS IS".
# * Complete and run the cells with the comment "COMPLETE THE MISSING PART AND RUN THIS CELL".
#
# For additional information about the available data and helper functions for Task 2, review the section named __Available data and helper functions for Task 2__ in the lab instructions.
#
# ### Setup and requirements for Task 2
#
# #### Import libraries

# %%
# "RUN THIS CELL AS IS"

# Import necessary packages and libraries.

from IPython.display import Markdown, display
from vertexai.generative_models import (
    Content,
    GenerationConfig,
    GenerationResponse,
    GenerativeModel,
    HarmCategory,
    HarmBlockThreshold,
    Image,
    Part,
)

# %% [markdown]
# #### Load the Gemini 2.0 Flash model

# %%
# "RUN THIS CELL AS IS"

# Load the Gemini 2.0 Flash model.

multimodal_model = GenerativeModel("gemini-2.5-flash")

# %% [markdown]
# #### Download custom Python modules and utilities
#
# The cell below will download some helper functions needed for this notebook, to improve readability. You can also view the code (`intro_multimodal_rag_utils.py`) directly on [GitHub](https://raw.githubusercontent.com/GoogleCloudPlatform/generative-ai/main/gemini/use-cases/retrieval-augmented-generation/utils/intro_multimodal_rag_utils.py).

# %%
# "RUN THIS CELL AS IS"

# Import necessary packages and libraries.
import os
import urllib.request
import sys

if not os.path.exists("utils"):
    os.makedirs("utils")


# Download the helper scripts from utils folder.
url_prefix = "https://raw.githubusercontent.com/GoogleCloudPlatform/generative-ai/main/gemini/use-cases/retrieval-augmented-generation/utils/"
files = ["intro_multimodal_rag_utils.py"]

for fname in files:
    urllib.request.urlretrieve(f"{url_prefix}/{fname}", filename=f"utils/{fname}")

# %% [markdown]
# #### Get documents and images from Cloud Storage

# %%
# "RUN THIS CELL AS IS"

# Download documents and images used in this notebook.

# !gsutil -m rsync -r gs://spls/gsp520 .
print("Download completed")
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Building synchronization state...
# Starting synchronization...
# Copying gs://spls/gsp520/Google_Branding/Dont_do_this_1.png...
# Copying gs://spls/gsp520/Google_Branding/.DS_Store...
# Copying gs://spls/gsp520/Google_Branding/Dont_do_this_2.png...
# Copying gs://spls/gsp520/Google_Branding/Ask_first_2.png...
# Copying gs://spls/gsp520/Google_Branding/Ask_first_3.png...
# Copying gs://spls/gsp520/Google_Branding/Go_for_it_1.png...
# Copying gs://spls/gsp520/Google_Branding/Go_for_it_2.png...
# Copying gs://spls/gsp520/Google_Branding/Go_for_it_3.png...
# Copying gs://spls/gsp520/Google_Branding/Dont_do_this_5.png...
# Copying gs://spls/gsp520/Google_Branding/Ask_first_1.png...
# Copying gs://spls/gsp520/Google_Branding/Dont_do_this_4.png...
# Copying gs://spls/gsp520/Google_Branding/Dont_do_this_3.png...
# Copying gs://spls/gsp520/Google_Branding/Go_for_it_4.png...
# Copying gs://spls/gsp520/Google_Branding/Go_for_it_6.png...
# Copying gs://spls/gsp520/Google_Branding/Dont_do_this_6.png...
# Copying gs://spls/gsp520/Google_Branding/Go_for_it_5.png...
# Copying gs://spls/gsp520/Google_Branding/Google_terms_of_service_en_us.pdf...
# Copying gs://spls/gsp520/google-pixel-8-pro.mp4...
# - [18/18 files][ 10.8 MiB/ 10.8 MiB] 100% Done
# Operation completed over 18 objects/10.8 MiB.
# Download completed

# %% [markdown]
# ### Task 2.1. Build metadata of documents containing text and images
#
# __Note__: These steps may take a few minutes to complete.
#
# #### Import helper functions to build metadata

# %%
# "RUN THIS CELL AS IS"

# Import helper functions from utils.
from utils.intro_multimodal_rag_utils import get_document_metadata
# Out:
# /home/jupyter/.local/lib/python3.12/site-packages/vertexai/_model_garden/_model_garden_models.py:278: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %% [markdown]
# #### Explore the variables of the task

# %%
# "RUN THIS CELL AS IS"

# You're going to work with provided variables in this task. 
# First, review and describe the content/purpose of each variable below. 


# Specify the "PDF folder path" with single PDF and "PDF folder" with multiple PDF.

pdf_folder_path = "Google_Branding/"  # if running in Vertex AI Workbench.

# Specify the image description prompt. Change it
image_description_prompt = """Explain what is going on in the image.
If it's a table, extract all elements of the table.
If it's a graph, explain the findings in the graph.
Do not include any numbers that are not mentioned in the image.
"""

# %% [markdown]
# #### Extract and store metadata of text and images from a document

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Call the "get_document_metadata" function from the utils file to extract text and image metadata from the PDF document. Store the results in two different DataFrames: "text_metadata_df" and "image_metadata_df".  
# text_metadata_df: This will contain extracted text snippets, their corresponding page numbers, and potentially other relevant information.
# image_metadata_df: This will contain descriptions of the images found in the PDF (if any), along with their location within the document.

text_metadata_df, image_metadata_df = get_document_metadata(
    multimodal_model, # we are passing gemini 1.0 pro vision model
    pdf_folder_path,
    image_save_dir="images",
    image_description_prompt=image_description_prompt,
    embedding_size=1408,
)

print("\n\n --- Completed processing. ---")
# Out:
#  Processing the file: --------------------------------- Google_Branding/Google_terms_of_service_en_us.pdf
#
#
# Processing page: 1
# Processing page: 2
# Processing page: 3
# Processing page: 4
# Processing page: 5
# Processing page: 6
# Processing page: 7
# Processing page: 8
# Processing page: 9
# Processing page: 10
# Processing page: 11
# Processing page: 12
# Processing page: 13
# Processing page: 14
# Processing page: 15
# Processing page: 16
#
#
#  --- Completed processing. ---

# %% [markdown]
# #### Inspect the processed text metadata

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Explore the text_metadata_df dataframe by displaying the first few rows of the dataframe.

text_metadata_df.head()
# Out:
#                            file_name  page_num  \
# 0  Google_terms_of_service_en_us.pdf         1
# 1  Google_terms_of_service_en_us.pdf         1
# 2  Google_terms_of_service_en_us.pdf         2
# 3  Google_terms_of_service_en_us.pdf         2
# 4  Google_terms_of_service_en_us.pdf         3
#
#                                                 text  \
# 0  GOOGLE TERMS OF SERVICE\nEffective January 5, ...
# 1  GOOGLE TERMS OF SERVICE\nEffective January 5, ...
# 2  Google services are provided by, and youre con...
# 3  Google services are provided by, and youre con...
# 4  apps and sites (like Search and Maps)\nplatfor...
#
#                                  text_embedding_page  chunk_number  \
# 0  [-0.012991457246243954, 0.00233408878557384, 0...             1
# 1  [-0.012991457246243954, 0.00233408878557384, 0...             2
# 2  [-0.027467481791973114, -0.03269978240132332, ...             1
# 3  [-0.027467481791973114, -0.03269978240132332, ...             2
# 4  [-0.024841992184519768, -0.016507208347320557,...             1
#
#                                           chunk_text  \
# 0  GOOGLE TERMS OF SERVICE\nEffective January 5, ...
# 1  ongs to you, Google, or others\nIn case of pro...
# 2  Google services are provided by, and youre con...
# 3  \nto use our services if you agree to follow t...
# 4  apps and sites (like Search and Maps)\nplatfor...
#
#                                 text_embedding_chunk
# 0  [-0.005565959494560957, 0.0008999718702398241,...
# 1  [-0.02242434397339821, -0.02287789061665535, -...
# 2  [-0.030542202293872833, -0.03709811717271805, ...
# 3  [-0.010060024447739124, -0.006401533726602793,...
# 4  [-0.022818822413682938, -0.026401124894618988,...

# %% [markdown]
# #### Import the helper functions to implement RAG

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Import helper functions from utils.

from utils.intro_multimodal_rag_utils import (
    get_similar_text_from_query,
    print_text_to_text_citation,
    get_similar_image_from_query,
    print_text_to_image_citation,
    get_gemini_response,
    display_images,
)

# %% [markdown]
# Proceed to Task 2.2 below (no progress check for Task 2.1 in lab instructions).
#
# ### Task 2.2. Create a user query
#
# #### Explore the variables of the task

# %%
# "RUN THIS CELL AS IS"

# You're going to work with provided variables in this task. 
# First, review and describe the content/purpose of each variable below. 

query = """Questions:
 - What are the key expectations that users can have from Google regarding the provision and development of its services?
- What specific rules and guidelines are established for users when using Google services?
- How does Google handle intellectual property rights related to the content found within its services, including content owned by users, Google, and third parties? 
- What legal rights and remedies are available to users in case of problems or disagreements with Google?
- How do the service-specific additional terms interact with these general Terms of Service, and which terms take precedence in case of any conflicts?
 """

# %% [markdown]
# Proceed to Task 2.3 below (no progress check for Task 2.2 in lab instructions).
#
# ### Task 2.3. Get all relevant text chunks
#
# #### Retrieve relevant chunks of text based on the query

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Call the "get_similar_text_from_query" function from the utils file to retrieve relevant chunks of text based on the query. Store the results in a dictionary called "matching_results_chunks_data".  
# matching_results_chunks_data: This dictionary will contain file_name, page_num, cosine_score, chunk_number and chunk_score. The dictionary represents a search result for a query related to the text_metadata_df.

matching_results_chunks_data = get_similar_text_from_query(
    query,
    text_metadata_df,
    column_name="text_embedding_chunk",
    top_n=10,
    chunk_text=True,
)

# %% [markdown]
# #### Display the first item of the text chunk dictionary

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Explore the first item in your matching_results_chunks_data dictionary by displaying the first item.

print_text_to_text_citation(
    matching_results_chunks_data,
    print_top=False,
    chunk_text=True,
)
# Out:
# Citation 1: Matched text:
# Score: 0.87
# File name: Google_terms_of_service_en_us.pdf
# Page: 1
# Page number: 1
# Chunk number: 1
# Chunk text: GOOGLE TERMS OF SERVICE
# Effective January 5, 2022
# Archived versions
# Whats covered in these terms
# We know its tempting to skip these Terms of Service, but
# its important to establish what you can expect from us as
# you use Google services, and what we expect from you.
# These Terms of Service reflect the way Googles business works, the laws that apply to our company, and
# certain things weve always believed to be true. As a result, these Terms of Service help define Googles
# relationship with you as you interact with our services. For example, these terms include the following topic
# headings:
# What you can expect from us, which describes how we provide and develop our services
# What we expect from you, which establishes certain rules for using our services
# Content in Google services, which describes the intellectual property rights to the content you find in our
# services  whether that content belongs to you, Google, or others
# In case of problems or disagreements, which describes other legal rig
# Citation 2: Matched text:
# Score: 0.83
# File name: Google_terms_of_service_en_us.pdf
# Page: 13
# Page number: 13
# Chunk number: 1
# Chunk text: About these terms
# By law, you have certain rights that cant be limited by a contract like these terms of service. These terms are
# in no way intended to restrict those rights.
# These terms describe the relationship between you and Google. They dont create any legal rights for other
# people or organizations, even if others benefit from that relationship under these terms.
# We want to make these terms easy to understand, so weve used examples from our services. But not all
# services mentioned may be available in your country.
# If these terms conflict with the service-specific additional terms, the additional terms will govern for that
# service.
# If it turns out that a particular term is not valid or enforceable, this will not affect any other terms.
# If you dont follow these terms or the service-specific additional terms, and we dont take action right away,
# that doesnt mean were giving up any rights that we may have, such as taking action in the future.
# We may update these terms and service-speci
# Citation 3: Matched text:
# Score: 0.8
# File name: Google_terms_of_service_en_us.pdf
# Page: 2
# Page number: 2
# Chunk number: 2
# Chunk text:
# to use our services if you agree to follow these terms, which reflect how Googles business works and how we
# earn money. When we speak of Google, we, us, and our, we mean Google LLC and its affiliates.
# What you can expect from us
# Provide a broad range of useful services
# We provide a broad range of services that are subject to these terms, including:
#
# Citation 4: Matched text:
# Score: 0.76
# File name: Google_terms_of_service_en_us.pdf
# Page: 11
# Page number: 11
# Chunk number: 1
# Chunk text: To the extent allowed by applicable law:
# Google is liable only for its breaches of these terms or applicable service-specific additional terms
# Google isnt liable for:
# loss of profits, revenues, business opportunities, goodwill, or anticipated savings
# indirect or consequential losses
# punitive damages
# Googles total liability arising out of or relating to these terms is limited to the greater of (1) $200 or (2)
# the fees paid to use the relevant services in the 12 months before the dispute
# For business users and organizations only
# If youre a business user or organization:
# To the extent allowed by applicable law, youll indemnify Google and its directors, officers, employees,
# and contractors for any third-party legal proceedings (including actions by government authorities)
# arising out of or relating to your unlawful use of the services or violation of these terms or service-
# specific additional terms. This indemnity covers any liability or expense arising from claims, losses,
# damages, judgm
# Citation 5: Matched text:
# Score: 0.75
# File name: Google_terms_of_service_en_us.pdf
# Page: 13
# Page number: 13
# Chunk number: 2
# Chunk text: s that we may have, such as taking action in the future.
# We may update these terms and service-specific additional terms (1) to reflect changes in our services or how
# we do business  for example, when we add new services, features, technologies, pricing, or benefits (or
# remove old ones), (2) for legal, regulatory, or security reasons, or (3) to prevent abuse or harm.
# If we materially change these terms or service-specific additional terms, well provide you with reasonable
# advance notice and the opportunity to review the changes, except (1) when we launch a new service or
# feature, or (2) in urgent situations, such as preventing ongoing abuse or responding to legal requirements. If
# you dont agree to the new terms, you should remove your content and stop using the services. You can also
# end your relationship with us at any time by closing your Google Account.
# DEFINITIONS
# affiliate
# An entity that belongs to the Google group of companies, which means Google LLC and its subsidiaries,
# includi
# Citation 6: Matched text:
# Score: 0.74
# File name: Google_terms_of_service_en_us.pdf
# Page: 3
# Page number: 3
# Chunk number: 2
# Chunk text:  to our services, and start offering new services or stop
# offering old ones. When a service requires or includes downloadable software, that software sometimes
# updates automatically on your device once a new version or feature is available. Some services let you adjust
# your automatic update settings.
# If we make material changes that negatively impact your use of our services or if we stop offering a service,
# well provide you with reasonable advance notice, except in urgent situations such as preventing abuse,
# responding to legal requirements, or addressing security and operability issues. Well also provide you with an
# opportunity to export your content from your Google Account using Google Takeout, subject to applicable
# law and policies.
# What we expect from you
# Follow these terms and service-specific additional terms
# The permission we give you to use our services continues as long as you comply with:
# these terms
#
# Citation 7: Matched text:
# Score: 0.74
# File name: Google_terms_of_service_en_us.pdf
# Page: 4
# Page number: 4
# Chunk number: 1
# Chunk text: service-specific additional terms, which could, for example, include things like additional age
# requirements
# You also agree that our Privacy Policy applies to your use of our services. Additionally, we provide resources
# like the Copyright Help Center, Safety Center, and descriptions of our technologies from our policies site to
# answer common questions and to set expectations about using our services.
# Although we give you permission to use our services, we retain any intellectual property rights we have in the
# services.
# Respect others
# We want to maintain a respectful environment for everyone, which means you must follow these basic rules
# of conduct:
# comply with applicable laws, including export control, sanctions, and human trafficking laws
# respect the rights of others, including privacy and intellectual property rights
# dont abuse or harm others or yourself (or threaten or encourage such abuse or harm)  for example, by
# misleading, defrauding, illegally impersonating, defaming, bullying,
# Citation 8: Matched text:
# Score: 0.74
# File name: Google_terms_of_service_en_us.pdf
# Page: 5
# Page number: 5
# Chunk number: 1
# Chunk text: to provide. If you choose to upload or share content, please make sure you have the necessary rights to do so
# and that the content is lawful.
# License
# Your content remains yours, which means that you retain any intellectual property rights that you
# have in your content. For example, you have intellectual property rights in the creative content you
# make, such as reviews you write. Or you may have the right to share someone elses creative content
# if theyve given you their permission.
# We need your permission if your intellectual property rights restrict our use of your content. You
# provide Google with that permission through this license.
# Whats covered
# This license covers your content if that content is protected by intellectual property rights.
# Whats not covered
# This license doesnt affect your privacy rights  its only about your intellectual property rights
# This license doesnt cover these types of content:
# publicly-available factual information that you provide, such as corrections to the
# Citation 9: Matched text:
# Score: 0.74
# File name: Google_terms_of_service_en_us.pdf
# Page: 7
# Page number: 7
# Chunk number: 1
# Chunk text: using content youve shared publicly to promote the services. For example, to promote a
# Google app, we might quote a review you wrote. Or to promote Google Play, we might show a
# screenshot of the app you offer in the Play Store.
# developing new technologies and services for Google consistent with these terms
# Duration
# This license lasts for as long as your content is protected by intellectual property rights.
# If you remove from our services any content thats covered by this license, then our systems will stop
# making that content publicly available in a reasonable amount of time. There are two exceptions:
# If you already shared your content with others before removing it. For example, if you shared a
# photo with a friend who then made a copy of it, or shared it again, then that photo may
# continue to appear in your friends Google Account even after you remove it from your Google
# Account.
# If you make your content available through other companies services, its possible that search
# engines, inc
# Citation 10: Matched text:
# Score: 0.73
# File name: Google_terms_of_service_en_us.pdf
# Page: 8
# Page number: 8
# Chunk number: 1
# Chunk text: Using Google services on behalf of an organization or business
# Many organizations, such as businesses, non-profits, and schools, take advantage of our services. To use
# our services on behalf of an organization:
# an authorized representative of that organization must agree to these terms
# your organizations administrator may assign a Google Account to you. That administrator might
# require you to follow additional rules and may be able to access or disable your Google Account.
# Service-related communications
# To provide you with our services, we sometimes send you service announcements and other information. To
# learn more about how we communicate with you, see Googles Privacy Policy.
# If you choose to give us feedback, such as suggestions to improve our services, we may act on your feedback
# without obligation to you.
# Content in Google services
# Your content
# Some of our services give you the opportunity to make your content publicly available  for example, you
# might post a product or restaurant

# %% [markdown]
# Proceed to Task 2.4 below (no progress check for Task 2.3 in lab instructions).
#
# ### Task 2.4. Create context_text
#
# #### Create a list to store the combined chunks of text

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"


# Create an empty list named "context_text". This list will be used to store the combined chunks of text.
context_text = list()

# %% [markdown]
# #### Iterate through each item in the text chunks dictionary

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Create a for loop to iterate through each item in the matching_results_chunks_data dictionary in order to combine all the selected relevant text chunks

for key, value in matching_results_chunks_data.items():
    context_text.append(value["chunk_text"])

# %% [markdown]
# #### Join all the text chunks and store in a list

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Take all of the individual text chunks stored in the context_text list and join them together into a single string named final_context_text. Use "\n" part inserts a newline character between each chunk, effectively creating separate lines or paragraphs.

final_context_text = "\n".join(context_text)

# %% [markdown]
# Proceed to Task 2.5 below (no progress check for Task 2.4 in lab instructions).
#
# ### Task 2.5. Pass context to Gemini
#
# #### Explore the variables of the task

# %%
# "RUN THIS CELL AS IS"

# You're going to work with provided variables in this task. First, review and describe the content/purpose of each variable below. 

prompt = f""" Instructions: Compare the images and the text provided as Context: to answer multiple Question:
Make sure to think thoroughly before answering the question and put the necessary steps to arrive at the answer in bullet points for easy explainability.
If unsure, respond, "Not enough context to answer".

Context:
 - Text Context:
 {final_context_text}


{query}

Answer:
"""

# %% [markdown]
# #### Generate Gemini response with streaming output

# %%
# "COMPLETE THE MISSING PART AND RUN THIS CELL"

# Call "get_gemini_response" function from utils module in order to generate Gemini response with streaming output. This function uses a multimodal Gemini model, a text prompt, and configuration parameters and instructs the Gemini model to generate a response using the provided prompt. As Gemini model enables streaming, you will receive chunks of the response as they were produced. 
# Format the streamed output using Markdown syntax for easy readability and conversion to HTML.

Markdown(
    get_gemini_response(
        multimodal_model,
        model_input=[prompt],
        stream=True,
        generation_config=GenerationConfig(temperature=0.2, max_output_tokens=2048),
    )
)
# Out:
# Here are the answers to your questions based on the provided Google Terms of Service:
#
# **1. What are the key expectations that users can have from Google regarding the provision and development of its services?**
#
# Users can expect the following from Google regarding the provision and development of its services:
# *   **Provision of a broad range of useful services:** Google provides a wide array of services subject to these terms.
# *   **Service Updates and Changes:** Google may update its services, add new features, technologies, or benefits, or remove old ones.
# *   **Automatic Software Updates:** When a service requires downloadable software, it may update automatically on the user's device, though some services allow adjusting update settings.
# *   **Advance Notice for Material Changes:** If Google makes material changes that negatively impact service use or stops offering a service, it will provide reasonable advance notice (except in urgent situations like preventing abuse, responding to legal requirements, or addressing security/operability issues).
# *   **Opportunity to Export Content:** In cases of material negative changes or service discontinuation, Google will provide an opportunity to export content from a Google Account using Google Takeout, subject to applicable law and policies.
#
# **2. What specific rules and guidelines are established for users when using Google services?**
#
# Users are expected to follow these specific rules and guidelines when using Google services:
# *   **Compliance with Terms:** Users must comply with these general Terms of Service and any service-specific additional terms (which may include things like additional age requirements).
# *   **Agreement to Privacy Policy:** Users agree that Google's Privacy Policy applies to their use of services.
# *   **Respect for Others:** Users must maintain a respectful environment by:
#     *   Complying with applicable laws (including export control, sanctions, and human trafficking laws).
#     *   Respecting the rights of others, including privacy and intellectual property rights.
#     *   Not abusing or harming others or themselves (or threatening/encouraging such abuse or harm), which includes misleading, defrauding, illegally impersonating, defaming, or bullying.
# *   **Content Rights and Lawfulness:** If users choose to upload or share content, they must ensure they have the necessary rights to do so and that the content is lawful.
#
# **3. How does Google handle intellectual property rights related to the content found within its services, including content owned by users, Google, and third parties?**
#
# Google handles intellectual property rights as follows:
# *   **User Content:**
#     *   **Ownership:** User content remains theirs; users retain any intellectual property rights they have in their content (e.g., creative content like reviews).
#     *   **License to Google:** Users grant Google a license to use their intellectual property-protected content if Google's use is restricted by those rights. This license allows Google to:
#         *   Host, reproduce, distribute, communicate, and use the content.
#         *   Publish, publicly perform, or publicly display the content if the user has made it publicly available.
#         *   Modify and create derivative works (e.g., reformatting for different devices).
#         *   Sub-license these rights to others for operating, promoting, and improving services.
#     *   **Purpose of License:** This license is for the limited purpose of operating, promoting, and improving Google's services, and developing new ones.
#     *   **Duration:** The license lasts as long as the content is protected by intellectual property rights.
#     *   **Removal:** If content is removed, Google's systems will stop making it publicly available in a reasonable time, with exceptions for content already shared with others or made available through other companies' services (which search engines might still index).
#     *   **What's Not Covered by License:** The license does not affect privacy rights, nor does it cover publicly-available factual information (like corrections to maps) or content not protected by IP rights.
# *   **Google's Intellectual Property:** Google retains any intellectual property rights it has in its services, even though it grants users permission to use them.
# *   **Third-Party Content:** The text mentions "Content in Google services, which describes the intellectual property rights to the content you find in our services - whether that content belongs to you, Google, or others," but does not elaborate on specific handling of third-party owned content beyond acknowledging its existence. Users are expected to respect the intellectual property rights of others.
#
# **4. What legal rights and remedies are available to users in case of problems or disagreements with Google?**
#
# In case of problems or disagreements with Google, users have the following legal rights and remedies:
# *   **Statutory Rights:** By law, users have certain rights that cannot be limited by a contract like these terms of service. These terms are not intended to restrict those rights.
# *   **Google's Liability:** To the extent allowed by applicable law, Google is liable only for its breaches of these terms or applicable service-specific additional terms.
# *   **Limitations on Google's Liability:** Google is *not* liable for:
#     *   Loss of profits, revenues, business opportunities, goodwill, or anticipated savings.
#     *   Indirect or consequential losses.
#     *   Punitive damages.
# *   **Total Liability Cap:** Google's total liability arising out of or relating to these terms is limited to the greater of (1) $200 or (2) the fees paid to use the relevant services in the 12 months before the dispute.
# *   **Opportunity to Review Changes:** If Google materially changes the terms, users will receive reasonable advance notice and an opportunity to review the changes.
# *   **Ending Relationship:** If users don't agree to new terms, they should remove their content and stop using the services. They can also end their relationship with Google at any time by closing their Google Account.
#
# **5. How do the service-specific additional terms interact with these general Terms of Service, and which terms take precedence in case of any conflicts?**
#
# *   **Interaction:** Service-specific additional terms provide further rules and guidelines that apply to particular Google services, supplementing the general Terms of Service.
# *   **Precedence:** If these general terms conflict with the service-specific additional terms, **the additional terms will govern for that specific service.**

# %% [markdown]
# ### To verify your work for Task 2.5, click __Check my progress__ in the lab instructions.

# %%
import base64
from IPython.display import display, HTML

# 1. Read the local image file and encode it
with open("logo.png", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read()).decode('utf-8')

# 2. Create the data URI for the HTML src attribute
b64_image_data = f"data:image/png;base64,{encoded_string}"

# 3. Inject it directly into the HTML
display(HTML(f'''
<div style="text-align: center; padding: 25px; background-color: #ffffff; border: 2px solid #1a73e8; border-radius: 12px; margin-bottom: 25px; box-shadow: 0 4px 6px rgba(0,0,0,0.1);">
    <img src="{b64_image_data}" width="250" />
    <h1 style="color: #1a73e8; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin-top: 15px;">Orbit of Ops</h1>
    <p style="color: #5f6368; font-size: 1.1em;"><i>Optimizing Operations via Intelligence</i></p>
    <hr style="width: 50%; border: 0; border-top: 1px solid #eee; margin: 15px auto;">
    <a href="https://orbitofops.com" style="color: #1a73e8; text-decoration: none; font-weight: bold;">orbitofops.com</a>
</div>
'''))
# Out:
# <div style="text-align: center; padding: 25px; background-color: #ffffff; border: 2px solid #1a73e8; border-radius: 12px; margin-bottom: 25px; box-shadow: 0 4px 6px rgba(0,0,0,0.1);">
#     <img src="data:image/png;base64,..." width="250" />
#     <h1 style="color: #1a73e8; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin-top: 15px;">Orbit of Ops</h1>
#     <p style="color: #5f6368; font-size: 1.1em;"><i>Optimizing Operations via Intelligence</i></p>
#     <hr style="width: 50%; border: 0; border-top: 1px solid #eee; margin: 15px auto;">
#     <a href="https://orbitofops.com" style="color: #1a73e8; text-decoration: none; font-weight: bold;">orbitofops.com</a>
# </div>
